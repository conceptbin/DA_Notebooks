# %% [markdown]
# # Exploring, filtering, grouping and viewing data in [pandas](https://pandas.pydata.org/)
# Demonstration notebook, using UK Police data on street-level crime in the London Metropolitan region, from https://data.police.uk/

# %%
import pandas as pd
import seaborn as sns
#Set max row and max column for display in Jupyter Notebook
pd.set_option('display.max_row', 150)
pd.set_option('display.max_columns', 20)

# %%
# Set Seaborn styling parameters for plots
sns.set(rc={'figure.figsize':(15,10)}) # Set figure size for all plots
sns.set_context("notebook") # Set how plots are displayed

# %% [markdown]
# # Read and inspect data
# The sample data here is Metropolitan Police cases, in CSV format. We use `read_csv()` to load the file.

# %%
# File path
file = r'data\2022-02-metropolitan-street.csv'
# Create dataframe (df)
df = pd.read_csv(file)

# %% [markdown]
# ## Dimensions of the dataframe

# %%
# Show the top rows
df.head()
# Out:
#                                             Crime ID    Month  \
# 0  86dcb4e75aee5e4f85faba482ae99f4b45d5ee7f694464...  2022-02
# 1  a8a306e3f41d1ef9b5601f0ee3f31b9bbfdbe41a64e3dc...  2022-02
# 2  ea3405ba86a84efdc8c67421ec725550e88f31be484be3...  2022-02
# 3  70b5893bdb519eb2613e3bb932f9b7a9a3462a76e9d6df...  2022-02
# 4                                                NaN  2022-02
#
#                    Reported by                 Falls within  Longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service   0.882064
# 1  Metropolitan Police Service  Metropolitan Police Service   0.875087
# 2  Metropolitan Police Service  Metropolitan Police Service  -0.972477
# 3  Metropolitan Police Service  Metropolitan Police Service  -0.804674
# 4  Metropolitan Police Service  Metropolitan Police Service   0.137065
#
#     Latitude                        Location  LSOA code  \
# 0  51.173592       On or near Goat Lees Lane  E01032810
# 1  51.151602        On or near Hardinge Road  E01024021
# 2  51.996811         On or near Jarman Close  E01017644
# 3  51.823998  On or near Rainborough Gardens  E01017662
# 4  51.583672       On or near Police Station  E01000027
#
#                    LSOA name                    Crime type  \
# 0               Ashford 001F  Violence and sexual offences
# 1               Ashford 004G  Violence and sexual offences
# 2        Aylesbury Vale 002A         Theft from the person
# 3        Aylesbury Vale 015C  Violence and sexual offences
# 4  Barking and Dagenham 001A         Anti-social behaviour
#
#                            Last outcome category  Context
# 0                            Under investigation      NaN
# 1                            Under investigation      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3                            Under investigation      NaN
# 4                                            NaN      NaN

# %% [markdown]
# List the column headings for the dataframe. Handy for selecting columns

# %%
df.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')

# %%
# Size of the dataframe (count of rows and columns):
df.shape
# Out:
# (80278, 12)

# %% [markdown]
# ## Handling empty values with isna() and dropna()

# %%
# Summarise the empty values in df by column
df.isna().sum()
# Out:
# Crime ID                 15589
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                 1894
# Latitude                  1894
# Location                     0
# LSOA code                 1894
# LSOA name                 1894
# Crime type                   0
# Last outcome category    15589
# Context                  80278
# dtype: int64

# %%
# Remove rows with empty values (NaN) in the 'LSOA name' column:
df = df.dropna(subset=['LSOA code'])

# %%
#Check if the NaN values have been dropped from df
df.isna().sum()
# Out:
# Crime ID                 15588
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                    0
# Latitude                     0
# Location                     0
# LSOA code                    0
# LSOA name                    0
# Crime type                   0
# Last outcome category    15588
# Context                  78384
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78384 entries, 0 to 78383
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               62796 non-null  object
#  1   Month                  78384 non-null  object
#  2   Reported by            78384 non-null  object
#  3   Falls within           78384 non-null  object
#  4   Longitude              78384 non-null  float64
#  5   Latitude               78384 non-null  float64
#  6   Location               78384 non-null  object
#  7   LSOA code              78384 non-null  object
#  8   LSOA name              78384 non-null  object
#  9   Crime type             78384 non-null  object
#  10  Last outcome category  62796 non-null  object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 7.8+ MB

# %% [markdown]
# ## Show head, tail or slice
# Show the first 10 rows: `df.head()`, last rows:` df.tail()`. Show slice by index number: `df[:5]` (shows first five rows).
#
# For large dataframes, the name of the dataframe will display the head and tail, omitting the middle.

# %%
df.head()
# Out:
#                                             Crime ID    Month  \
# 0  86dcb4e75aee5e4f85faba482ae99f4b45d5ee7f694464...  2022-02
# 1  a8a306e3f41d1ef9b5601f0ee3f31b9bbfdbe41a64e3dc...  2022-02
# 2  ea3405ba86a84efdc8c67421ec725550e88f31be484be3...  2022-02
# 3  70b5893bdb519eb2613e3bb932f9b7a9a3462a76e9d6df...  2022-02
# 4                                                NaN  2022-02
#
#                    Reported by                 Falls within  Longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service   0.882064
# 1  Metropolitan Police Service  Metropolitan Police Service   0.875087
# 2  Metropolitan Police Service  Metropolitan Police Service  -0.972477
# 3  Metropolitan Police Service  Metropolitan Police Service  -0.804674
# 4  Metropolitan Police Service  Metropolitan Police Service   0.137065
#
#     Latitude                        Location  LSOA code  \
# 0  51.173592       On or near Goat Lees Lane  E01032810
# 1  51.151602        On or near Hardinge Road  E01024021
# 2  51.996811         On or near Jarman Close  E01017644
# 3  51.823998  On or near Rainborough Gardens  E01017662
# 4  51.583672       On or near Police Station  E01000027
#
#                    LSOA name                    Crime type  \
# 0               Ashford 001F  Violence and sexual offences
# 1               Ashford 004G  Violence and sexual offences
# 2        Aylesbury Vale 002A         Theft from the person
# 3        Aylesbury Vale 015C  Violence and sexual offences
# 4  Barking and Dagenham 001A         Anti-social behaviour
#
#                            Last outcome category  Context
# 0                            Under investigation      NaN
# 1                            Under investigation      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3                            Under investigation      NaN
# 4                                            NaN      NaN

# %%
df.tail()
# Out:
#                                                 Crime ID    Month  \
# 78379  b68f44f18861ffe06f9ea799143aed99bf8a2f87f2c524...  2022-02
# 78380  b68f44f18861ffe06f9ea799143aed99bf8a2f87f2c524...  2022-02
# 78381  c6c0b645845e38959535cf6a480fdf82e2f50b4f54e9b1...  2022-02
# 78382  5fab93112c690e306203ad8e8d75a3b034e0f19ecca21c...  2022-02
# 78383  34901688fa2dff163ffad7d36032b66f6650666937d759...  2022-02
#
#                        Reported by                 Falls within  Longitude  \
# 78379  Metropolitan Police Service  Metropolitan Police Service  -0.757678
# 78380  Metropolitan Police Service  Metropolitan Police Service  -0.757678
# 78381  Metropolitan Police Service  Metropolitan Police Service  -0.687446
# 78382  Metropolitan Police Service  Metropolitan Police Service  -2.316703
# 78383  Metropolitan Police Service  Metropolitan Police Service  -1.062010
#
#         Latitude                      Location  LSOA code         LSOA name  \
# 78379  51.632691  On or near West Wycombe Road  E01017837      Wycombe 015B
# 78380  51.632691  On or near West Wycombe Road  E01017837      Wycombe 015B
# 78381  51.600977     On or near Millstream Way  E01017934      Wycombe 019A
# 78382  52.375612        On or near Supermarket  E01032428  Wyre Forest 011B
# 78383  53.979251     On or near Carrnock Court  E01013406         York 005B
#
#                          Crime type Last outcome category  Context
# 78379  Violence and sexual offences   Under investigation      NaN
# 78380  Violence and sexual offences   Under investigation      NaN
# 78381  Violence and sexual offences   Under investigation      NaN
# 78382                   Shoplifting   Under investigation      NaN
# 78383  Violence and sexual offences   Under investigation      NaN

# %%
#Show a slice of the rows by index
df[200:205]
# Out:
#                                               Crime ID    Month  \
# 200  4e1600ef85f3292c53d90bd0e1e7a8e95d5b9737ad09e0...  2022-02
# 201  ae6682676d616c26d9a6cb89996bf3780ea0960e58bd85...  2022-02
# 202  14fd11fed32e57e4de2a3b6b5147743c82c6a3fd2bf83c...  2022-02
# 203  c27dbc3f84a83decf58a035b14d817434449f755d2696c...  2022-02
# 204  324889a93e5545b84e96468508c6036c2714830dbe96f8...  2022-02
#
#                      Reported by                 Falls within  Longitude  \
# 200  Metropolitan Police Service  Metropolitan Police Service   0.179952
# 201  Metropolitan Police Service  Metropolitan Police Service   0.178142
# 202  Metropolitan Police Service  Metropolitan Police Service   0.178904
# 203  Metropolitan Police Service  Metropolitan Police Service   0.178904
# 204  Metropolitan Police Service  Metropolitan Police Service   0.179945
#
#       Latitude                    Location  LSOA code  \
# 200  51.560464    On or near Foxglove Road  E01000039
# 201  51.559113   On or near Bluebell Close  E01000039
# 202  51.557849   On or near Valentines Way  E01000039
# 203  51.557849   On or near Valentines Way  E01000039
# 204  51.557299  On or near Eastbrook Drive  E01000039
#
#                      LSOA name                    Crime type  \
# 200  Barking and Dagenham 003D                 Bicycle theft
# 201  Barking and Dagenham 003D                         Drugs
# 202  Barking and Dagenham 003D                   Other theft
# 203  Barking and Dagenham 003D  Violence and sexual offences
# 204  Barking and Dagenham 003D  Violence and sexual offences
#
#                              Last outcome category  Context
# 200  Investigation complete; no suspect identified      NaN
# 201                  Offender given penalty notice      NaN
# 202                            Under investigation      NaN
# 203                            Under investigation      NaN
# 204                            Under investigation      NaN

# %% [markdown]
# ## value_counts()
# For categorical data, show the number of occurrences. In this case, number of incidents for each 'Crime type' category:

# %%
df['Crime type'].value_counts()
# Out:
# Violence and sexual offences    19363
# Anti-social behaviour           15588
# Other theft                      8622
# Vehicle crime                    7971
# Burglary                         4192
# Theft from the person            4167
# Public order                     4109
# Criminal damage and arson        3868
# Drugs                            3522
# Shoplifting                      2781
# Robbery                          1897
# Bicycle theft                    1066
# Other crime                       839
# Possession of weapons             399
# Name: Crime type, dtype: int64

# %% [markdown]
# ## info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78384 entries, 0 to 78383
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               62796 non-null  object
#  1   Month                  78384 non-null  object
#  2   Reported by            78384 non-null  object
#  3   Falls within           78384 non-null  object
#  4   Longitude              78384 non-null  float64
#  5   Latitude               78384 non-null  float64
#  6   Location               78384 non-null  object
#  7   LSOA code              78384 non-null  object
#  8   LSOA name              78384 non-null  object
#  9   Crime type             78384 non-null  object
#  10  Last outcome category  62796 non-null  object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 7.8+ MB

# %% [markdown]
# # Selecting and filtering data

# %% [markdown]
# Select only columns containing categorical data ('object' type) with `select_dtypes()` and summarise with `describe()`

# %%
(df.select_dtypes(include=['object'])).describe()
# Out:
#                                                  Crime ID    Month  \
# count                                               62796    78384
# unique                                              59757        1
# top     1378fa1115fab67debaa500bc1cf4b158dad3aea04c1e1...  2022-02
# freq                                                    7    78384
#
#                         Reported by                 Falls within  \
# count                         78384                        78384
# unique                            1                            1
# top     Metropolitan Police Service  Metropolitan Police Service
# freq                          78384                        78384
#
#                       Location  LSOA code         LSOA name  \
# count                    78384      78384             78384
# unique                   20011       5154              5154
# top     On or near Supermarket  E01033595  Westminster 013E
# freq                      2986        824               824
#
#                           Crime type Last outcome category
# count                          78384                 62796
# unique                            14                     8
# top     Violence and sexual offences   Under investigation
# freq                           19363                 45297

# %% [markdown]
# ## Slice string
# Create a new column with the Borough name, so that we can select rows by borough. The `slice` function returns a defined segment of the text (or *string*) in the "LSOA name" column and copies it to a new column.

# %%
#Create a Borough-column:
df['Borough'] = df['LSOA name'].str.slice(0, -5)

# %% [markdown]
# ## List unique values by column

# %%
df['Borough'].unique()
# Out:
# array(['Ashford', 'Aylesbury Vale', 'Barking and Dagenham', 'Barnet',
#        'Barnsley', 'Basildon', 'Basingstoke and Deane', 'Bedford',
#        'Bexley', 'Birmingham', 'Blackpool', 'Boston', 'Bracknell Forest',
#        'Breckland', 'Brent', 'Brentwood', 'Brighton and Hove', 'Bristol',
#        'Bromley', 'Broxbourne', 'Burnley', 'Camden', 'Cannock Chase',
#        'Canterbury', 'Carmarthenshire', 'Castle Point',
#        'Central Bedfordshire', 'Charnwood', 'Chelmsford', 'Cherwell',
#        'Chichester', 'Chiltern', 'City of London', 'Colchester',
#        'Cornwall', 'Cotswold', 'Coventry', 'Craven', 'Crawley', 'Croydon',
#        'Dacorum', 'Dartford', 'Doncaster', 'Dover', 'Ealing',
#        'East Hertfordshire', 'East Lindsey', 'East Riding of Yorkshire',
#        'Elmbridge', 'Enfield', 'Epping Forest', 'Epsom and Ewell',
#        'Exeter', 'Fareham', 'Flintshire', 'Gravesham', 'Great Yarmouth',
#        'Greenwich', 'Guildford', 'Hackney', 'Hammersmith and Fulham',
#        'Haringey', 'Harlow', 'Harrow', 'Havant', 'Havering', 'Hertsmere',
#        'Hillingdon', 'Horsham', 'Hounslow', 'Ipswich', 'Islington',
#        'Kensington and Chelsea', "King's Lynn and West Norfolk",
#        'Kingston upon Hull', 'Kingston upon Thames', 'Kirklees',
#        'Lambeth', 'Leeds', 'Leicester', 'Lewisham', 'Lichfield',
#        'Liverpool', 'Luton', 'Maidstone', 'Maldon', 'Malvern Hills',
#        'Manchester', 'Medway', 'Merton', 'Mid Sussex', 'Milton Keynes',
#        'Mole Valley', 'Neath Port Talbot', 'Newham', 'Northampton',
#        'North East Lincolnshire', 'North Hertfordshire', 'North Somerset',
#        'North West Leicestershire', 'Nottingham', 'Oxford',
#        'Pembrokeshire', 'Peterborough', 'Portsmouth', 'Reading',
#        'Redbridge', 'Reigate and Banstead', 'Ribble Valley',
#        'Richmond upon Thames', 'Rochford', 'Rother', 'Rotherham',
#        'Runnymede', 'Rushmoor', 'Salford', 'Sandwell', 'Sevenoaks',
#        'Shepway', 'Slough', 'Southampton', 'South Bucks',
#        'Southend-on-Sea', 'South Norfolk', 'South Staffordshire',
#        'Southwark', 'Spelthorne', 'St Albans', 'Stevenage', 'St. Helens',
#        'Suffolk Coastal', 'Sunderland', 'Surrey Heath', 'Sutton', 'Swale',
#        'Swansea', 'Tameside', 'Tandridge', 'Teignbridge',
#        'Telford and Wrekin', 'Tendring', 'Test Valley', 'Thanet',
#        'Three Rivers', 'Thurrock', 'Tonbridge and Malling',
#        'Tower Hamlets', 'Trafford', 'Tunbridge Wells', 'Uttlesford',
#        'Vale of White Horse', 'Wakefield', 'Walsall', 'Waltham Forest',
#        'Wandsworth', 'Watford', 'Wealden', 'Welwyn Hatfield',
#        'West Berkshire', 'Westminster', 'West Somerset', 'Wigan',
#        'Wiltshire', 'Windsor and Maidenhead', 'Woking', 'Wokingham',
#        'Wolverhampton', 'Worcester', 'Wycombe', 'Wyre Forest', 'York'],
#       dtype=object)

# %% [markdown]
# Now that we know that the dataset includes incidents that took place outside of London, let's select only the London Boroughs in the dataset (just as we would use a filter in Excel).

# %% [markdown]
# ## Select with contains()
# Select with a keyword. Good for single-keyword filtering, or stringing conditions together with & or | ('or')

# %%
#Create separate dataframe for selected borough using part of the name
df_select = df[df['LSOA name'].str.contains('Leeds')]

# %%
df_select
# Out:
#                                                 Crime ID    Month  \
# 49513  3468fc8ff18b7f8b2817b39a275ca1f7d52fdb8e61ebd9...  2022-02
# 49514  992069eb46a88f997830c8654d87ffd85ba21d64b073b8...  2022-02
#
#                        Reported by                 Falls within  Longitude  \
# 49513  Metropolitan Police Service  Metropolitan Police Service  -1.558532
# 49514  Metropolitan Police Service  Metropolitan Police Service  -1.519335
#
#         Latitude                   Location  LSOA code   LSOA name  \
# 49513  53.836029   On or near Towers Square  E01011513  Leeds 031A
# 49514  53.802084  On or near Gargrave Place  E01011349  Leeds 065D
#
#                          Crime type Last outcome category  Context Borough
# 49513                   Other crime   Under investigation      NaN   Leeds
# 49514  Violence and sexual offences   Under investigation      NaN   Leeds

# %%
#Check the shape of df_select. This shows us how many cases (rows) the borough has
df_select.shape
# Out:
# (2, 13)

# %% [markdown]
# ## Select with isin()
# Select rows using a list of values.

# %%
#List of London Boroughs, plus City of London
LB_list = ['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley','Camden', 'City of London', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey',
       'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth',
       'Lewisham','Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
       'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']
# Filter the dataframe to include only names in the list:
df = df[df['Borough'].isin(LB_list)]

# %%
#Check which Boroughs are left in the df now:
df['Borough'].unique()
# Out:
# array(['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'City of London', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'], dtype=object)

# %%
len(df)
# Out:
# 77970

# %% [markdown]
# # Group and aggregate
# Functions: `groupby()`, `agg()`.

# %% [markdown]
# Let's compare the boroughs by how many incidents are recorded for each.

# %%
df.keys() # Same as columns() above.
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context', 'Borough'],
#       dtype='object')

# %% [markdown]
# ## groupby()
# Which borough has the most crime? We group the data by the "Borough" column, and sum up the total number of cases.

# %%
# Group by Borough, count total number of incidents, sort from highest to lowest
df_grouped = df.groupby(['Borough'])['Crime type'].agg('count').reset_index().sort_values(by=['Crime type'], ascending=False)

# %%
# Show first 10 rows of grouped dataframe
df_grouped
# Out:
#                    Borough  Crime type
# 32             Westminster        6014
# 24                  Newham        3465
# 29           Tower Hamlets        3208
# 5                   Camden        3104
# 7                  Croydon        3030
# 21                 Lambeth        3007
# 27               Southwark        2957
# 3                    Brent        2856
# 8                   Ealing        2849
# 9                  Enfield        2796
# 11                 Hackney        2755
# 1                   Barnet        2702
# 18               Islington        2681
# 13                Haringey        2614
# 22                Lewisham        2521
# 16              Hillingdon        2490
# 10               Greenwich        2426
# 31              Wandsworth        2413
# 25               Redbridge        2297
# 17                Hounslow        2269
# 30          Waltham Forest        2134
# 4                  Bromley        2134
# 19  Kensington and Chelsea        1878
# 12  Hammersmith and Fulham        1865
# 0     Barking and Dagenham        1825
# 15                Havering        1783
# 2                   Bexley        1550
# 14                  Harrow        1471
# 28                  Sutton        1281
# 23                  Merton        1269
# 20    Kingston upon Thames        1105
# 26    Richmond upon Thames        1090
# 6           City of London         131

# %% [markdown]
# **Task:** Can this data be grouped differently? Experiment with a separate dataframe for comparison (e.g., df_grouped2).

# %%
df.keys()
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context', 'Borough'],
#       dtype='object')

# %%
# Another grouping, by crime type, borough and using "LSOA code" for counting the number of instances.
df_grouped2 = df.groupby(['Crime type', 'Borough'])['LSOA code'].agg('count').reset_index().sort_values(by=['Borough'], ascending=False)

# %%
# Show the dataframe
df_grouped2
# Out:
#                        Crime type               Borough  LSOA code
# 459  Violence and sexual offences           Westminster        909
# 393         Theft from the person           Westminster       1147
# 131     Criminal damage and arson           Westminster        132
# 229                   Other theft           Westminster       1225
# 164                         Drugs           Westminster        237
# ..                            ...                   ...        ...
# 132                         Drugs  Barking and Dagenham        131
# 99      Criminal damage and arson  Barking and Dagenham        109
# 66                       Burglary  Barking and Dagenham         93
# 33                  Bicycle theft  Barking and Dagenham          9
# 230         Possession of weapons  Barking and Dagenham          8
#
# [460 rows x 3 columns]

# %%
# Here's a selected view showing bicycle thefts by borough
(df_grouped2[df_grouped2['Crime type'].str.contains('bicycle', case=False)]).sort_values(by='LSOA code', ascending=False)
# Out:
#        Crime type                 Borough  LSOA code
# 60  Bicycle theft               Southwark         99
# 62  Bicycle theft           Tower Hamlets         94
# 38  Bicycle theft                  Camden         68
# 44  Bicycle theft                 Hackney         68
# 64  Bicycle theft              Wandsworth         63
# 54  Bicycle theft                 Lambeth         58
# 65  Bicycle theft             Westminster         57
# 51  Bicycle theft               Islington         56
# 45  Bicycle theft  Hammersmith and Fulham         52
# 43  Bicycle theft               Greenwich         39
# 52  Bicycle theft  Kensington and Chelsea         38
# 50  Bicycle theft                Hounslow         36
# 59  Bicycle theft    Richmond upon Thames         34
# 57  Bicycle theft                  Newham         31
# 55  Bicycle theft                Lewisham         30
# 36  Bicycle theft                   Brent         29
# 46  Bicycle theft                Haringey         27
# 53  Bicycle theft    Kingston upon Thames         27
# 41  Bicycle theft                  Ealing         24
# 63  Bicycle theft          Waltham Forest         23
# 34  Bicycle theft                  Barnet         20
# 56  Bicycle theft                  Merton         17
# 58  Bicycle theft               Redbridge         12
# 37  Bicycle theft                 Bromley          9
# 49  Bicycle theft              Hillingdon          9
# 48  Bicycle theft                Havering          9
# 33  Bicycle theft    Barking and Dagenham          9
# 42  Bicycle theft                 Enfield          7
# 61  Bicycle theft                  Sutton          6
# 47  Bicycle theft                  Harrow          5
# 40  Bicycle theft                 Croydon          3
# 35  Bicycle theft                  Bexley          3
# 39  Bicycle theft          City of London          1

# %% [markdown]
# ### Simple bar chart comparing the number of cases by borough.

# %%
sns.barplot(data=df_grouped, x="Crime type", y="Borough")
# Out:
# <Axes: xlabel='Crime type', ylabel='Borough'>

# %% [markdown]
# ## Crosstab
# Compare data across categories with `crosstab()`. A a cross-tabulation table shows the frequency with which certain groups of data appear.
#
# The Practical Business Python blog has a good summary of Pandas' crosstab function: [Pandas Crosstab Explained](https://pbpython.com/pandas-crosstab.html)

# %% [markdown]
# ### Simple crosstab
# Crime types broken down by Borough.

# %%
df_crossed = pd.crosstab(df['Borough'], df['Crime type']).sort_values(by=['Borough'], ascending=True)

# %%
df_crossed
# Out:
# Crime type              Anti-social behaviour  Bicycle theft  Burglary  \
# Borough
# Barking and Dagenham                      336              9        93
# Barnet                                    576             20       202
# Bexley                                    273              3        81
# Brent                                     605             29       178
# Bromley                                   362              9       132
# Camden                                    624             68       179
# City of London                              8              1         7
# Croydon                                   586              3       161
# Ealing                                    629             24       132
# Enfield                                   495              7       172
# Greenwich                                 437             39       146
# Hackney                                   544             68       171
# Hammersmith and Fulham                    402             52       103
# Haringey                                  494             27       135
# Harrow                                    351              5        77
# Havering                                  333              9        96
# Hillingdon                                545              9       112
# Hounslow                                  505             36       108
# Islington                                 612             56       122
# Kensington and Chelsea                    397             38        93
# Kingston upon Thames                      246             27        52
# Lambeth                                   657             58       137
# Lewisham                                  457             30       189
# Merton                                    261             17        77
# Newham                                    647             31       136
# Redbridge                                 407             12       122
# Richmond upon Thames                      230             34        67
# Southwark                                 595             99       198
# Sutton                                    248              6        77
# Tower Hamlets                             827             94       178
# Waltham Forest                            440             23        84
# Wandsworth                                480             63       147
# Westminster                               978             57       226
#
# Crime type              Criminal damage and arson  Drugs  Other crime  \
# Borough
# Barking and Dagenham                          109    131           36
# Barnet                                        134     86           32
# Bexley                                        131     48           24
# Brent                                         138    159           38
# Bromley                                       140     73           31
# Camden                                        116    139           17
# City of London                                  4      2            0
# Croydon                                       183    190           37
# Ealing                                        167    110           19
# Enfield                                       136    135           44
# Greenwich                                     133    137           28
# Hackney                                       142     99           19
# Hammersmith and Fulham                         86     55           18
# Haringey                                      132    113           30
# Harrow                                         75     58           16
# Havering                                      112     90           26
# Hillingdon                                    139     81           68
# Hounslow                                      135     86           25
# Islington                                     122     99           14
# Kensington and Chelsea                         87     56           12
# Kingston upon Thames                           54     62            9
# Lambeth                                       147    163           22
# Lewisham                                      144    114           22
# Merton                                         49     45           22
# Newham                                        142    227           48
# Redbridge                                     112     96           28
# Richmond upon Thames                           59     38            8
# Southwark                                     127    133           30
# Sutton                                         80     38            6
# Tower Hamlets                                 166    180           31
# Waltham Forest                                110    130           20
# Wandsworth                                    113     99           31
# Westminster                                   132    237           20
#
# Crime type              Other theft  Possession of weapons  Public order  \
# Borough
# Barking and Dagenham            162                      8            77
# Barnet                          246                     12           135
# Bexley                          147                      6            87
# Brent                           266                     10           161
# Bromley                         183                     14           103
# Camden                          497                     14           156
# City of London                   47                      0             2
# Croydon                         253                     24           174
# Ealing                          234                     11           178
# Enfield                         250                     27           126
# Greenwich                       229                     16           151
# Hackney                         307                     13           136
# Hammersmith and Fulham          196                      9           127
# Haringey                        229                     14           171
# Harrow                          123                      3            65
# Havering                        159                      6           103
# Hillingdon                      231                     12           154
# Hounslow                        204                     13           144
# Islington                       331                      8           154
# Kensington and Chelsea          303                      4            98
# Kingston upon Thames            106                      8            48
# Lambeth                         337                     20           146
# Lewisham                        245                      6           147
# Merton                          127                      9            64
# Newham                          363                     14           147
# Redbridge                       267                     13           107
# Richmond upon Thames            100                      3            71
# Southwark                       385                     20           119
# Sutton                           95                      7            90
# Tower Hamlets                   296                     14           149
# Waltham Forest                  211                     19           100
# Wandsworth                      229                     14           131
# Westminster                    1225                     26           278
#
# Crime type              Robbery  Shoplifting  Theft from the person  \
# Borough
# Barking and Dagenham         58           36                     35
# Barnet                       49           91                     80
# Bexley                       16           69                     20
# Brent                        69           76                     98
# Bromley                      31          209                     32
# Camden                       82           96                    318
# City of London                5            6                     30
# Croydon                      60           97                     52
# Ealing                       49           84                     72
# Enfield                      59          100                     65
# Greenwich                    49           85                     47
# Hackney                     120           68                    180
# Hammersmith and Fulham       34           83                     80
# Haringey                     87           83                    129
# Harrow                       31           44                     69
# Havering                     25           90                     40
# Hillingdon                   39          109                     54
# Hounslow                     29           77                     33
# Islington                    66           77                    241
# Kensington and Chelsea       42           94                    127
# Kingston upon Thames          7           32                     82
# Lambeth                      87           72                    156
# Lewisham                     50           92                     50
# Merton                       36           49                     23
# Newham                       74          133                    327
# Redbridge                    62           91                     92
# Richmond upon Thames         22           46                     35
# Southwark                   111           57                    171
# Sutton                       21           62                     26
# Tower Hamlets                62           50                    111
# Waltham Forest               73           74                     73
# Wandsworth                   54           78                     67
# Westminster                 235          266                   1147
#
# Crime type              Vehicle crime  Violence and sexual offences
# Borough
# Barking and Dagenham              181                           554
# Barnet                            407                           632
# Bexley                            170                           475
# Brent                             313                           716
# Bromley                           238                           577
# Camden                            218                           580
# City of London                      6                            13
# Croydon                           320                           890
# Ealing                            370                           770
# Enfield                           416                           764
# Greenwich                         202                           727
# Hackney                           239                           649
# Hammersmith and Fulham            173                           447
# Haringey                          340                           630
# Harrow                            168                           386
# Havering                          226                           468
# Hillingdon                        298                           639
# Hounslow                          239                           635
# Islington                         165                           614
# Kensington and Chelsea            210                           317
# Kingston upon Thames              100                           272
# Lambeth                           203                           802
# Lewisham                          292                           683
# Merton                            140                           350
# Newham                            422                           754
# Redbridge                         272                           616
# Richmond upon Thames              156                           221
# Southwark                         241                           671
# Sutton                            150                           375
# Tower Hamlets                     304                           746
# Waltham Forest                    216                           561
# Wandsworth                        260                           647
# Westminster                       278                           909

# %% [markdown]
# #### Heatmap of crosstab

# %%
sns.heatmap(df_crossed)
# Out:
# <Axes: xlabel='Crime type', ylabel='Borough'>

# %% [markdown]
# **Task:** Would it make sense to show only specific columns? Which ones?

# %% [markdown]
# #### Histogram of selected crime type
# Shows distribution by crime category.

# %%
sns.displot(df_crossed, x="Violence and sexual offences")
# Out:
# c:\Users\gauti.sigthorsson\Miniconda3\envs\py310\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Histogram of multiple categories
# Here we select multiple columns and instruct Seaborn to display the multiple categories as "stack".

# %%
sns.displot(
    df_crossed[['Anti-social behaviour','Other theft', 'Violence and sexual offences']],
    multiple="stack"
    )
# Out:
# c:\Users\gauti.sigthorsson\Miniconda3\envs\py310\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Compare frequency of selected crime category across boroughs
# First we transform the crosstab dataframe (reindex, sort), and then plot the result:

# %%
df_crossed.keys()
# Out:
# Index(['Anti-social behaviour', 'Bicycle theft', 'Burglary',
#        'Criminal damage and arson', 'Drugs', 'Other crime', 'Other theft',
#        'Possession of weapons', 'Public order', 'Robbery', 'Shoplifting',
#        'Theft from the person', 'Vehicle crime',
#        'Violence and sexual offences'],
#       dtype='object', name='Crime type')

# %%
# Transformation:
# Reset the index for df_crossed to flatten the dataframe
df_crossed.reset_index(inplace=True)
# Name of category to compare (allows us to change category quickly)
crime_category = "Theft from the person"
# Sort the dataframe by the selected category
df_crossed.sort_values(by=[f'{crime_category}'], ascending=False, inplace=True)

# %% [markdown]
# Here's the head() showing the top 5 rows for the selected columns (Borough, crime_category):

# %%
df_crossed[['Borough', f'{crime_category}']].head()
# Out:
# Crime type      Borough  Theft from the person
# 32          Westminster                   1147
# 24               Newham                    327
# 5                Camden                    318
# 18            Islington                    241
# 11              Hackney                    180

# %%
# Display bar plot:
sns.barplot(data=df_crossed, x=f"{crime_category}", y="Borough")
# Out:
# <Axes: xlabel='Theft from the person', ylabel='Borough'>

# %% [markdown]
# **Task:** Change the crime_category variable above and run the cells again to see how the plot changes.

# %% [markdown]
# ### Crosstab with margins
# The `margins` parameter adds a row at the bottom and column at the end summarising each. The name can be specified with `margins_name`.

# %%
df_crossed_margins = pd.crosstab(df['Borough'], df['Crime type'], margins=True, margins_name='Crimes total').reset_index()

# %%
df_crossed_margins
# Out:
# Crime type                 Borough  Anti-social behaviour  Bicycle theft  \
# 0             Barking and Dagenham                    336              9
# 1                           Barnet                    576             20
# 2                           Bexley                    273              3
# 3                            Brent                    605             29
# 4                          Bromley                    362              9
# 5                           Camden                    624             68
# 6                   City of London                      8              1
# 7                          Croydon                    586              3
# 8                           Ealing                    629             24
# 9                          Enfield                    495              7
# 10                       Greenwich                    437             39
# 11                         Hackney                    544             68
# 12          Hammersmith and Fulham                    402             52
# 13                        Haringey                    494             27
# 14                          Harrow                    351              5
# 15                        Havering                    333              9
# 16                      Hillingdon                    545              9
# 17                        Hounslow                    505             36
# 18                       Islington                    612             56
# 19          Kensington and Chelsea                    397             38
# 20            Kingston upon Thames                    246             27
# 21                         Lambeth                    657             58
# 22                        Lewisham                    457             30
# 23                          Merton                    261             17
# 24                          Newham                    647             31
# 25                       Redbridge                    407             12
# 26            Richmond upon Thames                    230             34
# 27                       Southwark                    595             99
# 28                          Sutton                    248              6
# 29                   Tower Hamlets                    827             94
# 30                  Waltham Forest                    440             23
# 31                      Wandsworth                    480             63
# 32                     Westminster                    978             57
# 33                    Crimes total                  15587           1063
#
# Crime type  Burglary  Criminal damage and arson  Drugs  Other crime  \
# 0                 93                        109    131           36
# 1                202                        134     86           32
# 2                 81                        131     48           24
# 3                178                        138    159           38
# 4                132                        140     73           31
# 5                179                        116    139           17
# 6                  7                          4      2            0
# 7                161                        183    190           37
# 8                132                        167    110           19
# 9                172                        136    135           44
# 10               146                        133    137           28
# 11               171                        142     99           19
# 12               103                         86     55           18
# 13               135                        132    113           30
# 14                77                         75     58           16
# 15                96                        112     90           26
# 16               112                        139     81           68
# 17               108                        135     86           25
# 18               122                        122     99           14
# 19                93                         87     56           12
# 20                52                         54     62            9
# 21               137                        147    163           22
# 22               189                        144    114           22
# 23                77                         49     45           22
# 24               136                        142    227           48
# 25               122                        112     96           28
# 26                67                         59     38            8
# 27               198                        127    133           30
# 28                77                         80     38            6
# 29               178                        166    180           31
# 30                84                        110    130           20
# 31               147                        113     99           31
# 32               226                        132    237           20
# 33              4190                       3856   3509          831
#
# Crime type  Other theft  Possession of weapons  Public order  Robbery  \
# 0                   162                      8            77       58
# 1                   246                     12           135       49
# 2                   147                      6            87       16
# 3                   266                     10           161       69
# 4                   183                     14           103       31
# 5                   497                     14           156       82
# 6                    47                      0             2        5
# 7                   253                     24           174       60
# 8                   234                     11           178       49
# 9                   250                     27           126       59
# 10                  229                     16           151       49
# 11                  307                     13           136      120
# 12                  196                      9           127       34
# 13                  229                     14           171       87
# 14                  123                      3            65       31
# 15                  159                      6           103       25
# 16                  231                     12           154       39
# 17                  204                     13           144       29
# 18                  331                      8           154       66
# 19                  303                      4            98       42
# 20                  106                      8            48        7
# 21                  337                     20           146       87
# 22                  245                      6           147       50
# 23                  127                      9            64       36
# 24                  363                     14           147       74
# 25                  267                     13           107       62
# 26                  100                      3            71       22
# 27                  385                     20           119      111
# 28                   95                      7            90       21
# 29                  296                     14           149       62
# 30                  211                     19           100       73
# 31                  229                     14           131       54
# 32                 1225                     26           278      235
# 33                 8583                    397          4099     1894
#
# Crime type  Shoplifting  Theft from the person  Vehicle crime  \
# 0                    36                     35            181
# 1                    91                     80            407
# 2                    69                     20            170
# 3                    76                     98            313
# 4                   209                     32            238
# 5                    96                    318            218
# 6                     6                     30              6
# 7                    97                     52            320
# 8                    84                     72            370
# 9                   100                     65            416
# 10                   85                     47            202
# 11                   68                    180            239
# 12                   83                     80            173
# 13                   83                    129            340
# 14                   44                     69            168
# 15                   90                     40            226
# 16                  109                     54            298
# 17                   77                     33            239
# 18                   77                    241            165
# 19                   94                    127            210
# 20                   32                     82            100
# 21                   72                    156            203
# 22                   92                     50            292
# 23                   49                     23            140
# 24                  133                    327            422
# 25                   91                     92            272
# 26                   46                     35            156
# 27                   57                    171            241
# 28                   62                     26            150
# 29                   50                    111            304
# 30                   74                     73            216
# 31                   78                     67            260
# 32                  266                   1147            278
# 33                 2776                   4162           7933
#
# Crime type  Violence and sexual offences  Crimes total
# 0                                    554          1825
# 1                                    632          2702
# 2                                    475          1550
# 3                                    716          2856
# 4                                    577          2134
# 5                                    580          3104
# 6                                     13           131
# 7                                    890          3030
# 8                                    770          2849
# 9                                    764          2796
# 10                                   727          2426
# 11                                   649          2755
# 12                                   447          1865
# 13                                   630          2614
# 14                                   386          1471
# 15                                   468          1783
# 16                                   639          2490
# 17                                   635          2269
# 18                                   614          2681
# 19                                   317          1878
# 20                                   272          1105
# 21                                   802          3007
# 22                                   683          2521
# 23                                   350          1269
# 24                                   754          3465
# 25                                   616          2297
# 26                                   221          1090
# 27                                   671          2957
# 28                                   375          1281
# 29                                   746          3208
# 30                                   561          2134
# 31                                   647          2413
# 32                                   909          6014
# 33                                 19090         77970

# %% [markdown]
# ### Normalise
# We can instruct `crosstab()` to show proportions, rather than absolute numbers with the `normalize` parameter.

# %%
# Crosstabl normalised by column, rounding numbers to 2 decimal places
df_cross_pct_cols = pd.crosstab(df['Borough'], df['Crime type'], normalize='columns').round(2)

# %%
df_cross_pct_cols
# Out:
# Crime type              Anti-social behaviour  Bicycle theft  Burglary  \
# Borough
# Barking and Dagenham                     0.02           0.01      0.02
# Barnet                                   0.04           0.02      0.05
# Bexley                                   0.02           0.00      0.02
# Brent                                    0.04           0.03      0.04
# Bromley                                  0.02           0.01      0.03
# Camden                                   0.04           0.06      0.04
# City of London                           0.00           0.00      0.00
# Croydon                                  0.04           0.00      0.04
# Ealing                                   0.04           0.02      0.03
# Enfield                                  0.03           0.01      0.04
# Greenwich                                0.03           0.04      0.03
# Hackney                                  0.03           0.06      0.04
# Hammersmith and Fulham                   0.03           0.05      0.02
# Haringey                                 0.03           0.03      0.03
# Harrow                                   0.02           0.00      0.02
# Havering                                 0.02           0.01      0.02
# Hillingdon                               0.03           0.01      0.03
# Hounslow                                 0.03           0.03      0.03
# Islington                                0.04           0.05      0.03
# Kensington and Chelsea                   0.03           0.04      0.02
# Kingston upon Thames                     0.02           0.03      0.01
# Lambeth                                  0.04           0.05      0.03
# Lewisham                                 0.03           0.03      0.05
# Merton                                   0.02           0.02      0.02
# Newham                                   0.04           0.03      0.03
# Redbridge                                0.03           0.01      0.03
# Richmond upon Thames                     0.01           0.03      0.02
# Southwark                                0.04           0.09      0.05
# Sutton                                   0.02           0.01      0.02
# Tower Hamlets                            0.05           0.09      0.04
# Waltham Forest                           0.03           0.02      0.02
# Wandsworth                               0.03           0.06      0.04
# Westminster                              0.06           0.05      0.05
#
# Crime type              Criminal damage and arson  Drugs  Other crime  \
# Borough
# Barking and Dagenham                         0.03   0.04         0.04
# Barnet                                       0.03   0.02         0.04
# Bexley                                       0.03   0.01         0.03
# Brent                                        0.04   0.05         0.05
# Bromley                                      0.04   0.02         0.04
# Camden                                       0.03   0.04         0.02
# City of London                               0.00   0.00         0.00
# Croydon                                      0.05   0.05         0.04
# Ealing                                       0.04   0.03         0.02
# Enfield                                      0.04   0.04         0.05
# Greenwich                                    0.03   0.04         0.03
# Hackney                                      0.04   0.03         0.02
# Hammersmith and Fulham                       0.02   0.02         0.02
# Haringey                                     0.03   0.03         0.04
# Harrow                                       0.02   0.02         0.02
# Havering                                     0.03   0.03         0.03
# Hillingdon                                   0.04   0.02         0.08
# Hounslow                                     0.04   0.02         0.03
# Islington                                    0.03   0.03         0.02
# Kensington and Chelsea                       0.02   0.02         0.01
# Kingston upon Thames                         0.01   0.02         0.01
# Lambeth                                      0.04   0.05         0.03
# Lewisham                                     0.04   0.03         0.03
# Merton                                       0.01   0.01         0.03
# Newham                                       0.04   0.06         0.06
# Redbridge                                    0.03   0.03         0.03
# Richmond upon Thames                         0.02   0.01         0.01
# Southwark                                    0.03   0.04         0.04
# Sutton                                       0.02   0.01         0.01
# Tower Hamlets                                0.04   0.05         0.04
# Waltham Forest                               0.03   0.04         0.02
# Wandsworth                                   0.03   0.03         0.04
# Westminster                                  0.03   0.07         0.02
#
# Crime type              Other theft  Possession of weapons  Public order  \
# Borough
# Barking and Dagenham           0.02                   0.02          0.02
# Barnet                         0.03                   0.03          0.03
# Bexley                         0.02                   0.02          0.02
# Brent                          0.03                   0.03          0.04
# Bromley                        0.02                   0.04          0.03
# Camden                         0.06                   0.04          0.04
# City of London                 0.01                   0.00          0.00
# Croydon                        0.03                   0.06          0.04
# Ealing                         0.03                   0.03          0.04
# Enfield                        0.03                   0.07          0.03
# Greenwich                      0.03                   0.04          0.04
# Hackney                        0.04                   0.03          0.03
# Hammersmith and Fulham         0.02                   0.02          0.03
# Haringey                       0.03                   0.04          0.04
# Harrow                         0.01                   0.01          0.02
# Havering                       0.02                   0.02          0.03
# Hillingdon                     0.03                   0.03          0.04
# Hounslow                       0.02                   0.03          0.04
# Islington                      0.04                   0.02          0.04
# Kensington and Chelsea         0.04                   0.01          0.02
# Kingston upon Thames           0.01                   0.02          0.01
# Lambeth                        0.04                   0.05          0.04
# Lewisham                       0.03                   0.02          0.04
# Merton                         0.01                   0.02          0.02
# Newham                         0.04                   0.04          0.04
# Redbridge                      0.03                   0.03          0.03
# Richmond upon Thames           0.01                   0.01          0.02
# Southwark                      0.04                   0.05          0.03
# Sutton                         0.01                   0.02          0.02
# Tower Hamlets                  0.03                   0.04          0.04
# Waltham Forest                 0.02                   0.05          0.02
# Wandsworth                     0.03                   0.04          0.03
# Westminster                    0.14                   0.07          0.07
#
# Crime type              Robbery  Shoplifting  Theft from the person  \
# Borough
# Barking and Dagenham       0.03         0.01                   0.01
# Barnet                     0.03         0.03                   0.02
# Bexley                     0.01         0.02                   0.00
# Brent                      0.04         0.03                   0.02
# Bromley                    0.02         0.08                   0.01
# Camden                     0.04         0.03                   0.08
# City of London             0.00         0.00                   0.01
# Croydon                    0.03         0.03                   0.01
# Ealing                     0.03         0.03                   0.02
# Enfield                    0.03         0.04                   0.02
# Greenwich                  0.03         0.03                   0.01
# Hackney                    0.06         0.02                   0.04
# Hammersmith and Fulham     0.02         0.03                   0.02
# Haringey                   0.05         0.03                   0.03
# Harrow                     0.02         0.02                   0.02
# Havering                   0.01         0.03                   0.01
# Hillingdon                 0.02         0.04                   0.01
# Hounslow                   0.02         0.03                   0.01
# Islington                  0.03         0.03                   0.06
# Kensington and Chelsea     0.02         0.03                   0.03
# Kingston upon Thames       0.00         0.01                   0.02
# Lambeth                    0.05         0.03                   0.04
# Lewisham                   0.03         0.03                   0.01
# Merton                     0.02         0.02                   0.01
# Newham                     0.04         0.05                   0.08
# Redbridge                  0.03         0.03                   0.02
# Richmond upon Thames       0.01         0.02                   0.01
# Southwark                  0.06         0.02                   0.04
# Sutton                     0.01         0.02                   0.01
# Tower Hamlets              0.03         0.02                   0.03
# Waltham Forest             0.04         0.03                   0.02
# Wandsworth                 0.03         0.03                   0.02
# Westminster                0.12         0.10                   0.28
#
# Crime type              Vehicle crime  Violence and sexual offences
# Borough
# Barking and Dagenham             0.02                          0.03
# Barnet                           0.05                          0.03
# Bexley                           0.02                          0.02
# Brent                            0.04                          0.04
# Bromley                          0.03                          0.03
# Camden                           0.03                          0.03
# City of London                   0.00                          0.00
# Croydon                          0.04                          0.05
# Ealing                           0.05                          0.04
# Enfield                          0.05                          0.04
# Greenwich                        0.03                          0.04
# Hackney                          0.03                          0.03
# Hammersmith and Fulham           0.02                          0.02
# Haringey                         0.04                          0.03
# Harrow                           0.02                          0.02
# Havering                         0.03                          0.02
# Hillingdon                       0.04                          0.03
# Hounslow                         0.03                          0.03
# Islington                        0.02                          0.03
# Kensington and Chelsea           0.03                          0.02
# Kingston upon Thames             0.01                          0.01
# Lambeth                          0.03                          0.04
# Lewisham                         0.04                          0.04
# Merton                           0.02                          0.02
# Newham                           0.05                          0.04
# Redbridge                        0.03                          0.03
# Richmond upon Thames             0.02                          0.01
# Southwark                        0.03                          0.04
# Sutton                           0.02                          0.02
# Tower Hamlets                    0.04                          0.04
# Waltham Forest                   0.03                          0.03
# Wandsworth                       0.03                          0.03
# Westminster                      0.04                          0.05

# %%
# Normalised by rows
df_cross_pct_rows = pd.crosstab(df['Borough'], df['Crime type'], normalize='index').round(2)

# %%
df_cross_pct_rows
# Out:
# Crime type              Anti-social behaviour  Bicycle theft  Burglary  \
# Borough
# Barking and Dagenham                     0.18           0.00      0.05
# Barnet                                   0.21           0.01      0.07
# Bexley                                   0.18           0.00      0.05
# Brent                                    0.21           0.01      0.06
# Bromley                                  0.17           0.00      0.06
# Camden                                   0.20           0.02      0.06
# City of London                           0.06           0.01      0.05
# Croydon                                  0.19           0.00      0.05
# Ealing                                   0.22           0.01      0.05
# Enfield                                  0.18           0.00      0.06
# Greenwich                                0.18           0.02      0.06
# Hackney                                  0.20           0.02      0.06
# Hammersmith and Fulham                   0.22           0.03      0.06
# Haringey                                 0.19           0.01      0.05
# Harrow                                   0.24           0.00      0.05
# Havering                                 0.19           0.01      0.05
# Hillingdon                               0.22           0.00      0.04
# Hounslow                                 0.22           0.02      0.05
# Islington                                0.23           0.02      0.05
# Kensington and Chelsea                   0.21           0.02      0.05
# Kingston upon Thames                     0.22           0.02      0.05
# Lambeth                                  0.22           0.02      0.05
# Lewisham                                 0.18           0.01      0.07
# Merton                                   0.21           0.01      0.06
# Newham                                   0.19           0.01      0.04
# Redbridge                                0.18           0.01      0.05
# Richmond upon Thames                     0.21           0.03      0.06
# Southwark                                0.20           0.03      0.07
# Sutton                                   0.19           0.00      0.06
# Tower Hamlets                            0.26           0.03      0.06
# Waltham Forest                           0.21           0.01      0.04
# Wandsworth                               0.20           0.03      0.06
# Westminster                              0.16           0.01      0.04
#
# Crime type              Criminal damage and arson  Drugs  Other crime  \
# Borough
# Barking and Dagenham                         0.06   0.07         0.02
# Barnet                                       0.05   0.03         0.01
# Bexley                                       0.08   0.03         0.02
# Brent                                        0.05   0.06         0.01
# Bromley                                      0.07   0.03         0.01
# Camden                                       0.04   0.04         0.01
# City of London                               0.03   0.02         0.00
# Croydon                                      0.06   0.06         0.01
# Ealing                                       0.06   0.04         0.01
# Enfield                                      0.05   0.05         0.02
# Greenwich                                    0.05   0.06         0.01
# Hackney                                      0.05   0.04         0.01
# Hammersmith and Fulham                       0.05   0.03         0.01
# Haringey                                     0.05   0.04         0.01
# Harrow                                       0.05   0.04         0.01
# Havering                                     0.06   0.05         0.01
# Hillingdon                                   0.06   0.03         0.03
# Hounslow                                     0.06   0.04         0.01
# Islington                                    0.05   0.04         0.01
# Kensington and Chelsea                       0.05   0.03         0.01
# Kingston upon Thames                         0.05   0.06         0.01
# Lambeth                                      0.05   0.05         0.01
# Lewisham                                     0.06   0.05         0.01
# Merton                                       0.04   0.04         0.02
# Newham                                       0.04   0.07         0.01
# Redbridge                                    0.05   0.04         0.01
# Richmond upon Thames                         0.05   0.03         0.01
# Southwark                                    0.04   0.04         0.01
# Sutton                                       0.06   0.03         0.00
# Tower Hamlets                                0.05   0.06         0.01
# Waltham Forest                               0.05   0.06         0.01
# Wandsworth                                   0.05   0.04         0.01
# Westminster                                  0.02   0.04         0.00
#
# Crime type              Other theft  Possession of weapons  Public order  \
# Borough
# Barking and Dagenham           0.09                   0.00          0.04
# Barnet                         0.09                   0.00          0.05
# Bexley                         0.09                   0.00          0.06
# Brent                          0.09                   0.00          0.06
# Bromley                        0.09                   0.01          0.05
# Camden                         0.16                   0.00          0.05
# City of London                 0.36                   0.00          0.02
# Croydon                        0.08                   0.01          0.06
# Ealing                         0.08                   0.00          0.06
# Enfield                        0.09                   0.01          0.05
# Greenwich                      0.09                   0.01          0.06
# Hackney                        0.11                   0.00          0.05
# Hammersmith and Fulham         0.11                   0.00          0.07
# Haringey                       0.09                   0.01          0.07
# Harrow                         0.08                   0.00          0.04
# Havering                       0.09                   0.00          0.06
# Hillingdon                     0.09                   0.00          0.06
# Hounslow                       0.09                   0.01          0.06
# Islington                      0.12                   0.00          0.06
# Kensington and Chelsea         0.16                   0.00          0.05
# Kingston upon Thames           0.10                   0.01          0.04
# Lambeth                        0.11                   0.01          0.05
# Lewisham                       0.10                   0.00          0.06
# Merton                         0.10                   0.01          0.05
# Newham                         0.10                   0.00          0.04
# Redbridge                      0.12                   0.01          0.05
# Richmond upon Thames           0.09                   0.00          0.07
# Southwark                      0.13                   0.01          0.04
# Sutton                         0.07                   0.01          0.07
# Tower Hamlets                  0.09                   0.00          0.05
# Waltham Forest                 0.10                   0.01          0.05
# Wandsworth                     0.09                   0.01          0.05
# Westminster                    0.20                   0.00          0.05
#
# Crime type              Robbery  Shoplifting  Theft from the person  \
# Borough
# Barking and Dagenham       0.03         0.02                   0.02
# Barnet                     0.02         0.03                   0.03
# Bexley                     0.01         0.04                   0.01
# Brent                      0.02         0.03                   0.03
# Bromley                    0.01         0.10                   0.01
# Camden                     0.03         0.03                   0.10
# City of London             0.04         0.05                   0.23
# Croydon                    0.02         0.03                   0.02
# Ealing                     0.02         0.03                   0.03
# Enfield                    0.02         0.04                   0.02
# Greenwich                  0.02         0.04                   0.02
# Hackney                    0.04         0.02                   0.07
# Hammersmith and Fulham     0.02         0.04                   0.04
# Haringey                   0.03         0.03                   0.05
# Harrow                     0.02         0.03                   0.05
# Havering                   0.01         0.05                   0.02
# Hillingdon                 0.02         0.04                   0.02
# Hounslow                   0.01         0.03                   0.01
# Islington                  0.02         0.03                   0.09
# Kensington and Chelsea     0.02         0.05                   0.07
# Kingston upon Thames       0.01         0.03                   0.07
# Lambeth                    0.03         0.02                   0.05
# Lewisham                   0.02         0.04                   0.02
# Merton                     0.03         0.04                   0.02
# Newham                     0.02         0.04                   0.09
# Redbridge                  0.03         0.04                   0.04
# Richmond upon Thames       0.02         0.04                   0.03
# Southwark                  0.04         0.02                   0.06
# Sutton                     0.02         0.05                   0.02
# Tower Hamlets              0.02         0.02                   0.03
# Waltham Forest             0.03         0.03                   0.03
# Wandsworth                 0.02         0.03                   0.03
# Westminster                0.04         0.04                   0.19
#
# Crime type              Vehicle crime  Violence and sexual offences
# Borough
# Barking and Dagenham             0.10                          0.30
# Barnet                           0.15                          0.23
# Bexley                           0.11                          0.31
# Brent                            0.11                          0.25
# Bromley                          0.11                          0.27
# Camden                           0.07                          0.19
# City of London                   0.05                          0.10
# Croydon                          0.11                          0.29
# Ealing                           0.13                          0.27
# Enfield                          0.15                          0.27
# Greenwich                        0.08                          0.30
# Hackney                          0.09                          0.24
# Hammersmith and Fulham           0.09                          0.24
# Haringey                         0.13                          0.24
# Harrow                           0.11                          0.26
# Havering                         0.13                          0.26
# Hillingdon                       0.12                          0.26
# Hounslow                         0.11                          0.28
# Islington                        0.06                          0.23
# Kensington and Chelsea           0.11                          0.17
# Kingston upon Thames             0.09                          0.25
# Lambeth                          0.07                          0.27
# Lewisham                         0.12                          0.27
# Merton                           0.11                          0.28
# Newham                           0.12                          0.22
# Redbridge                        0.12                          0.27
# Richmond upon Thames             0.14                          0.20
# Southwark                        0.08                          0.23
# Sutton                           0.12                          0.29
# Tower Hamlets                    0.09                          0.23
# Waltham Forest                   0.10                          0.26
# Wandsworth                       0.11                          0.27
# Westminster                      0.05                          0.15

# %% [markdown]
# #### Histogram of normalised crime types

# %%
sns.displot(df_cross_pct_rows[['Other theft', 'Violence and sexual offences']], element="step")
# Out:
# c:\Users\gauti.sigthorsson\Miniconda3\envs\py310\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Proportion of crime types by Borough
# Heatmap of most frequent crime types for each borough. This enables us to identify "hot spots" within the dataset. The colour palette can be adjusted with the `cmap` parameter (see [Seaborn colour palettes documentation](https://seaborn.pydata.org/tutorial/color_palettes.html)).

# %%
sns.heatmap(df_cross_pct_rows, cmap="mako")
# Out:
# <Axes: xlabel='Crime type', ylabel='Borough'>

# %% [markdown]
# **Task:** Add `margins` to the normalised dataframes, to see proportional distribution between crime types.

# %% [markdown]
# # Output
# You can save a dataframe in various formats. The most-used methods for writing to file are `to_excel()` and `to_csv()`, and (more simply) copying to clipboard for pasting into Excel or similar software using `to_clipboard()`.

# %% [markdown]
# First, list your dataframes, using the `%who_ls` magic method.

# %%
# List all the dataframes in the notebook
# %who_ls DataFrame
# Out:
# ['df',
#  'df_cross_pct_cols',
#  'df_cross_pct_rows',
#  'df_crossed',
#  'df_crossed_margins',
#  'df_grouped',
#  'df_grouped2',
#  'df_select']

# %% [markdown]
# ## Copy to clipboard
# The commonly used to_clipboard() method is good for copy/pasting small datasets into Excel (or other spreadsheet software) on the fly.

# %%
# Copy to clipboard
df_cross_pct_rows.to_clipboard()
