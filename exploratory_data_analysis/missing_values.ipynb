# %% [markdown]
# # Missing values
# Visualising missing data with [the `missingno` library](https://github.com/ResidentMario/missingno).

# %%
# Package imports
import seaborn as sns
import pandas as pd
import missingno as msno

# %%
data_source = 'https://github.com/conceptbin/workshops/raw/main/pandas_data_analysis/data/2023-03-metropolitan-street.csv'
df = pd.read_csv(data_source)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92833 entries, 0 to 92832
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               76442 non-null  object
#  1   Month                  92833 non-null  object
#  2   Reported by            92833 non-null  object
#  3   Falls within           92833 non-null  object
#  4   Longitude              88786 non-null  float64
#  5   Latitude               88786 non-null  float64
#  6   Location               92833 non-null  object
#  7   LSOA code              88786 non-null  object
#  8   LSOA name              88786 non-null  object
#  9   Crime type             92833 non-null  object
#  10  Last outcome category  76442 non-null  object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 8.5+ MB

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>
